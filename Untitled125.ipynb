# %% [markdown]
# # ***Business Case Netflix - Data Exploration and Visualisation***

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('netflix.csv')

# %% [markdown]
# #**Data Descreption **

# %% [markdown]
# * 📌 show_id - Unique ID for every Movie/TV Show
# * 📌 type - Type of Content: Movie/TV Show
#
#
#
#
# * 📌 title - Name of the Movie/TV Show
# * 📌 director - Name of the Director of the Movie/TV Show
# * 📌 cast - Actors involved in the Movie/TV Show
# * 📌 country - Name of the Countries where the Movie/TV Show is produced
# * 📌 date_added - The Date in which the Movie/TV Show was added on Netflix
# * 📌 release_year - Original Release Year of the Movie/TV Show
# * 📌 rating - Rating of the Movie/TV Show
# * 📌 duration - Total Duration of the Movie (in Minutes) or TV Show (in Seasons)
# * 📌 listed_in - Genre of the Movie/TV Show
# * 📌 description - Summary of the Movie/TV Show

# %%
df.shape
# Out:
# (8807, 12)

# %%
len(df)
# Out:
# 8807

# %%
df.describe()
# Out:
#        release_year
# count   8807.000000
# mean    2014.180198
# std        8.819312
# min     1925.000000
# 25%     2013.000000
# 50%     2017.000000
# 75%     2019.000000
# max     2021.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   object
#  1   type          8807 non-null   object
#  2   title         8807 non-null   object
#  3   director      6173 non-null   object
#  4   cast          7982 non-null   object
#  5   country       7976 non-null   object
#  6   date_added    8797 non-null   object
#  7   release_year  8807 non-null   int64
#  8   rating        8803 non-null   object
#  9   duration      8804 non-null   object
#  10  listed_in     8807 non-null   object
#  11  description   8807 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 825.8+ KB

# %% [markdown]
# # ***Handling null values***
# a. For categorical variables with null values, update those rows as
# unknown_column_name.

# %%
df.isnull().sum()
# Out:
# show_id            0
# type               0
# title              0
# director        2634
# cast             825
# country          831
# date_added        10
# release_year       0
# rating             4
# duration           3
# listed_in          0
# description        0
# dtype: int64

# %% [markdown]
# # Drop the null values which are less than 5% from the entire data

# %%
df.dropna(subset = 'date_added',inplace = True)
df.dropna(subset = 'rating',inplace = True)
df.dropna(subset = 'duration',inplace = True)

# %%
df.isnull().sum()
# Out:
# show_id            0
# type               0
# title              0
# director        2621
# cast             825
# country          829
# date_added         0
# release_year       0
# rating             0
# duration           0
# listed_in          0
# description        0
# dtype: int64

# %%
df['director'].replace(np.nan,'No director',inplace = True)
df['cast'].replace(np.nan,'No cast',inplace = True)
df['country'].replace(np.nan,'No country',inplace = True)

# %%
df.isnull().sum()
# Out:
# show_id         0
# type            0
# title           0
# director        0
# cast            0
# country         0
# date_added      0
# release_year    0
# rating          0
# duration        0
# listed_in       0
# description     0
# dtype: int64

# %%
df.head(5)
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water      No director
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans      No director
# 4      s5  TV Show           Kota Factory      No director
#
#                                                 cast        country  \
# 0                                            No cast  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...     No country
# 3                                            No cast     No country
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %% [markdown]
# **seperating the time duration in the duration columns **

# %%
df['duration']
# Out:
# 0          90 min
# 1       2 Seasons
# 2        1 Season
# 3        1 Season
# 4       2 Seasons
#           ...
# 8802      158 min
# 8803    2 Seasons
# 8804       88 min
# 8805       88 min
# 8806      111 min
# Name: duration, Length: 8790, dtype: object

# %%
df['movie_duration'] = df['duration'].where(df['duration'].str.contains('min'),'')
df['season_duration'] = df['duration'].where(df['duration'].str.contains('Seasons','Season'),'')
df.drop('duration',axis = 1 ,inplace = True)

# %%
df.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water      No director
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans      No director
# 4      s5  TV Show           Kota Factory      No director
#
#                                                 cast        country  \
# 0                                            No cast  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...     No country
# 3                                            No cast     No country
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating  \
# 0  September 25, 2021          2020  PG-13
# 1  September 24, 2021          2021  TV-MA
# 2  September 24, 2021          2021  TV-MA
# ...

# %%
df['date_added'].dt.month
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-17-d59510e29364> in <cell line: 1>()
# ----> 1 df['date_added'].dt.month
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    5900         ):
#    5901             return self[name]
# -> 5902         return object.__getattribute__(self, name)
#    5903
#    5904     def __setattr__(self, name: str, value) -> None:
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/accessor.py in __get__(self, obj, cls)
#     180             # we're accessing the attribute of the class, i.e., Dataset.geo
#     181             return self._accessor
# --> 182         accessor_obj = self._accessor(obj)
#     183         # Replace the property with the accessor object. Inspired by:
#     184         # https://www.pydanny.com/cached-property.html
#
# ...

# %%
df['date_added'] = pd.to_datetime(df['date_added'],errors = 'coerce')

# %%
df['month'] = df['date_added'].dt.month
df['year'] = df['date_added'].dt.year

# %%
df.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water      No director
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans      No director
# 4      s5  TV Show           Kota Factory      No director
#
#                                                 cast        country  \
# 0                                            No cast  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...     No country
# 3                                            No cast     No country
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#   date_added  release_year rating  \
# 0 2021-09-25          2020  PG-13
# 1 2021-09-24          2021  TV-MA
# 2 2021-09-24          2021  TV-MA
# 3 2021-09-24          2021  TV-MA
# ...

# %%
df['cast']
# Out:
# 0                                                 No cast
# 1       Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...
# 2       Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...
# 3                                                 No cast
# 4       Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...
#                               ...
# 8802    Mark Ruffalo, Jake Gyllenhaal, Robert Downey J...
# 8803                                              No cast
# 8804    Jesse Eisenberg, Woody Harrelson, Emma Stone, ...
# 8805    Tim Allen, Courteney Cox, Chevy Chase, Kate Ma...
# 8806    Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...
# Name: cast, Length: 8790, dtype: object

# %% [markdown]
# # ***Un-nesting the columns***
# a. Un-nest the columns those have cells with multiple comma separated values by
# creating multiple rows

# %%
df['cast'] = df['cast'].str.split(',')
df = df.explode('cast')
df.reset_index(drop = True)
# Out:
#       show_id     type                 title         director  \
# 0          s1    Movie  Dick Johnson Is Dead  Kirsten Johnson
# 1          s2  TV Show         Blood & Water      No director
# 2          s2  TV Show         Blood & Water      No director
# 3          s2  TV Show         Blood & Water      No director
# 4          s2  TV Show         Blood & Water      No director
# ...       ...      ...                   ...              ...
# 64836   s8807    Movie                Zubaan      Mozez Singh
# 64837   s8807    Movie                Zubaan      Mozez Singh
# 64838   s8807    Movie                Zubaan      Mozez Singh
# 64839   s8807    Movie                Zubaan      Mozez Singh
# 64840   s8807    Movie                Zubaan      Mozez Singh
#
#                          cast        country date_added  release_year rating  \
# 0                     No cast  United States 2021-09-25          2020  PG-13
# ...

# %%
df.index = np.arange(1,len(df)+1)

# %%
df.head()
# Out:
#   show_id     type                 title         director             cast  \
# 1      s1    Movie  Dick Johnson Is Dead  Kirsten Johnson          No cast
# 2      s2  TV Show         Blood & Water      No director       Ama Qamata
# 3      s2  TV Show         Blood & Water      No director      Khosi Ngema
# 4      s2  TV Show         Blood & Water      No director    Gail Mabalane
# 5      s2  TV Show         Blood & Water      No director   Thabang Molaba
#
#          country date_added  release_year rating  \
# 1  United States 2021-09-25          2020  PG-13
# 2   South Africa 2021-09-24          2021  TV-MA
# 3   South Africa 2021-09-24          2021  TV-MA
# 4   South Africa 2021-09-24          2021  TV-MA
# 5   South Africa 2021-09-24          2021  TV-MA
#
#                                          listed_in  \
# 1                                    Documentaries
# 2  International TV Shows, TV Dramas, TV Mysteries
# 3  International TV Shows, TV Dramas, TV Mysteries
# ...

# %%
df['listed_in'] = df['listed_in'].str.split(',')
df = df.explode('listed_in')
df.reset_index(drop = True)
# Out:
#        show_id     type                 title         director  \
# 0           s1    Movie  Dick Johnson Is Dead  Kirsten Johnson
# 1           s2  TV Show         Blood & Water      No director
# 2           s2  TV Show         Blood & Water      No director
# 3           s2  TV Show         Blood & Water      No director
# 4           s2  TV Show         Blood & Water      No director
# ...        ...      ...                   ...              ...
# 149279   s8807    Movie                Zubaan      Mozez Singh
# 149280   s8807    Movie                Zubaan      Mozez Singh
# 149281   s8807    Movie                Zubaan      Mozez Singh
# 149282   s8807    Movie                Zubaan      Mozez Singh
# 149283   s8807    Movie                Zubaan      Mozez Singh
#
#                           cast        country date_added  release_year rating  \
# 0                      No cast  United States 2021-09-25          2020  PG-13
# ...

# %%
df.index = np.arange(1,len(df)+1)

# %%
df.head()
# Out:
#   show_id     type                 title         director          cast  \
# 1      s1    Movie  Dick Johnson Is Dead  Kirsten Johnson       No cast
# 2      s2  TV Show         Blood & Water      No director    Ama Qamata
# 3      s2  TV Show         Blood & Water      No director    Ama Qamata
# 4      s2  TV Show         Blood & Water      No director    Ama Qamata
# 5      s2  TV Show         Blood & Water      No director   Khosi Ngema
#
#          country date_added  release_year rating               listed_in  \
# 1  United States 2021-09-25          2020  PG-13           Documentaries
# 2   South Africa 2021-09-24          2021  TV-MA  International TV Shows
# 3   South Africa 2021-09-24          2021  TV-MA               TV Dramas
# 4   South Africa 2021-09-24          2021  TV-MA            TV Mysteries
# 5   South Africa 2021-09-24          2021  TV-MA  International TV Shows
#
#                                          description movie_duration  \
# ...

# %% [markdown]
# # ***Data Visualization***

# %% [markdown]
# Comparison of tv shows vs. movies.

# %%
plt.figure(figsize = (6,5))
sns.countplot(x= 'type' ,data = df ,width = 0.4,color = 'red')
plt.xlabel('TYPE',fontsize = 12 )
plt.ylabel('COUNT',fontsize = 10)
plt.title('MOVIE VS TV_SHOW')
plt.show()

# %%
df.head()
# Out:
#   show_id     type                 title         director          cast  \
# 1      s1    Movie  Dick Johnson Is Dead  Kirsten Johnson       No cast
# 2      s2  TV Show         Blood & Water      No director    Ama Qamata
# 3      s2  TV Show         Blood & Water      No director    Ama Qamata
# 4      s2  TV Show         Blood & Water      No director    Ama Qamata
# 5      s2  TV Show         Blood & Water      No director   Khosi Ngema
#
#          country date_added  release_year rating               listed_in  \
# 1  United States 2021-09-25          2020  PG-13           Documentaries
# 2   South Africa 2021-09-24          2021  TV-MA  International TV Shows
# 3   South Africa 2021-09-24          2021  TV-MA               TV Dramas
# 4   South Africa 2021-09-24          2021  TV-MA            TV Mysteries
# 5   South Africa 2021-09-24          2021  TV-MA  International TV Shows
#
#                                          description movie_duration  \
# ...

# %% [markdown]
# # **Top 10 Directors by the Number of Films and TV Shows They Directed**

# %%
director_count = df.groupby('director')['type'].count().sort_values(ascending = False)[1:11]

# %%
plt.figure(figsize = (12,8))
sns.countplot(x = 'director' , data = df ,order = director_count.index)
plt.title('TOP 10 DIRECTOR',fontsize = 15)
plt.xlabel('director',fontsize = 12 )
plt.ylabel('count',fontsize = 12 )
plt.xticks(rotation = 90 ,size = 12)
plt.show()

# %% [markdown]
#  ***Find the number of movies produced in each country and pick the top 10 countries***

# %%
top_10_country = df.groupby('country')['director'].count().sort_values(ascending = False)[1:11]
top_10_country
# Out:
# country
# India             19816
# No country        11142
# Japan              6504
# United Kingdom     5153
# South Korea        4234
# Spain              3370
# Mexico             2588
# Canada             2543
# Turkey             2446
# Nigeria            2229
# Name: director, dtype: int64

# %%
plt.figure(figsize = (12,8))
sns.countplot(x = 'country' , data = df ,order = top_10_country.index,color = 'green')
plt.title('Top 10 Country',fontsize = 15)
plt.xlabel('Country',fontsize = 12 )
plt.ylabel('count',fontsize = 12 )
plt.xticks(rotation = 90 ,size = 12)
plt.show()

# %% [markdown]
# ***Find the number of Tv-Shows produced in each country and pick the top 10
# countries.***

# %%
top10country = df[df['type'] == 'TV Show']['country'].value_counts().sort_values(ascending = False)[1:11]

# %%
plt.figure(figsize = (10,7))
sns.countplot(x = 'country' ,data = df , order = top10country.index)
plt.title('top 10 country',fontsize = 15)
plt.xlabel('country',fontsize = 12)
plt.ylabel('count',fontsize = 12)
plt.xticks(rotation = 90 , size = 12 )
plt.show()

# %%
A =  df[df['type'] == 'Movie']

# %%
A.groupby('country')['type'].count().sort_values(ascending = False)[1:11]
# Out:
# country
# India             18817
# No country         5706
# Japan              2055
# Nigeria            2014
# United Kingdom     2013
# Spain              1796
# Philippines        1667
# Indonesia          1660
# Egypt              1651
# Turkey             1640
# Name: type, dtype: int64

# %% [markdown]
# # ***What is the best time to launch a TV show?***
# a. Find which is the best week to release the Tv-show or the movie. Do the analysis
# separately for Tv-shows and Movies

# %%
df['week_number'] = df['date_added'].dt.isocalendar().week

# %%
weekno = df.groupby('week_number')['type'].count().sort_values(ascending = False)[:5]

# %%
sns.countplot(x = 'week_number',data = df , order = weekno.index)
# Out:
# <Axes: xlabel='week_number', ylabel='count'>

# %%
week_number = 26
year = 2008
first_day_of_year = pd.to_datetime(str(year), format='%Y')
first_monday = first_day_of_year + pd.DateOffset(weekday=0)
date_from_week = first_monday + pd.DateOffset(weeks=week_number - 1)
print("Date from week number {}: {}".format(week_number, date_from_week))
# Out:
# Date from week number 26: 2008-06-30 00:00:00

# %% [markdown]
# * Date from week number 1: 2008-01-07 00:00:00
# * Date from week number 44: 2008-11-03 00:00:00
# * Date from week number 40: 2008-10-06 00:00:00
# * Date from week number 35: 2008-09-01 00:00:00
# * Date from week number 26: 2008-06-30 00:00:00

# %%
month_number = 5
year = 2024

date_from_month = pd.to_datetime(str(year) + '-' + str(month_number) + '-01')

print("Date from month number {}: {}".format(month_number, date_from_month))
# Out:
# Date from month number 5: 2024-05-01 00:00:00

# %% [markdown]
#  Find which is the best month to release the Tv-show or the movie. Do the
# analysis separately for Tv-shows and Movies

# %%
top5month = df.groupby('month')['type'].count().sort_values(ascending = False)[:5]

# %%
sns.countplot(x = 'month' ,data = df , order = top5month.index)
# Out:
# <Axes: xlabel='month', ylabel='count'>

# %%
plt.figure(figsize=(10, 5))
sns.countplot(data=df, x='rating', order=df['rating'].value_counts().index)
plt.title('Distribution of Ratings')
plt.show()

# %%
shows = df.pivot_table(index="month", columns="year", values="show_id", aggfunc='size')
sns.heatmap(shows, cmap="YlGnBu", annot=False)
month_order = ['January', 'February', 'March', 'April', 'May', 'June', 'July', 'August', 'September', 'October', 'November', 'December']
plt.yticks(ticks=range(1, 13), labels=month_order, rotation=0)
plt.title("Distribution of Netflix Movies and TV Shows Added Over the Years")
plt.show()
